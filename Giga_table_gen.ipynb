# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
gini_data_df = pd.read_csv('./processed_datasets/gini_data.csv')
gini_data_df
# Out:
#            country alpha3  1991  1992  1993  1994  1995  1996  1997  1998  \
# 0          Albania    ALB   NaN   NaN   NaN   NaN   NaN  27.0   NaN   NaN
# 1        Argentina    ARG  46.8  45.5  44.8  45.9  48.9  49.5  49.1  50.7
# 2          Armenia    ARM   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3        Australia    AUS   NaN   NaN   NaN   NaN  32.6   NaN   NaN   NaN
# 4          Austria    AUT   NaN   NaN   NaN  30.8  29.9  29.3  29.1  31.3
# ..             ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 111  Venezuela, RB    VEN   NaN  42.1   NaN   NaN  47.2   NaN   NaN  48.0
# 112       Viet Nam    VNM   NaN  35.7   NaN   NaN   NaN   NaN  35.4   NaN
# 113         Kosovo    XKX   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 114   South Africa    ZAF   NaN   NaN  59.3   NaN   NaN   NaN   NaN   NaN
# 115         Zambia    ZMB  59.4   NaN  52.6   NaN   NaN  48.3   NaN  49.1
#
#      ...  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# ...

# %%
# Initialize an empty list to store DataFrames
df_list = []

for year in range(1990, 2021):  # Assuming the range of years is from 1991 to 2023
    year_column = str(year)
    
    # Check if the year exists as a column in the dataframe
    if year_column in gini_data_df.columns:
        # Create a new DataFrame with 'country', 'alpha3', and the value of that year
        df_year = gini_data_df[['country', 'alpha3', year_column]].copy()
        
        # Rename the column to 'gini' instead of 'value'
        df_year = df_year.rename(columns={year_column: 'gini'})
        
        # Add a new column 'year' to store the current year
        df_year['year'] = year
        
        # Rearrange the columns to ['country', 'year', 'alpha3', 'gini']
        df_year = df_year[['country', 'year', 'alpha3', 'gini']]
        
        # Append the DataFrame to the list
        df_list.append(df_year)

# Concatenate all the DataFrames in the list into a single DataFrame
merged_gini_data = pd.concat(df_list, ignore_index=True)

# Optionally, inspect the merged DataFrame
print(merged_gini_data.head())
# Out:
#      country  year alpha3  gini
# 0    Albania  1991    ALB   NaN
# 1  Argentina  1991    ARG  46.8
# 2    Armenia  1991    ARM   NaN
# 3  Australia  1991    AUS   NaN
# 4    Austria  1991    AUT   NaN

# %%
literacy_data_pd = pd.read_csv('./processed_datasets/literacy_data.csv')
literacy_data_pd
# Out:
#                          country alpha3       1991       1992       1993  \
# 0    Africa Eastern and Southern    AFE  58.141190  58.530640  58.912601
# 1     Africa Western and Central    AFW  44.823318  45.163380  46.002171
# 2                        Albania    ALB        NaN        NaN        NaN
# 3                     Arab World    ARB  55.813911  56.863861  57.682941
# 4                        Armenia    ARM        NaN        NaN        NaN
# ..                           ...    ...        ...        ...        ...
# 109                     Viet Nam    VNM        NaN        NaN        NaN
# 110                      Vanuatu    VUT        NaN        NaN        NaN
# 111                        World    WLD  75.198761  75.645752  76.059624
# 112                 South Africa    ZAF        NaN        NaN        NaN
# 113                       Zambia    ZMB        NaN        NaN        NaN
#
#           1994       1995       1996       1997       1998  ...       2014  \
# ...

# %%
# Initialize an empty list to store DataFrames
df_list = []

for year in range(1990, 2021):  # Assuming the range of years is from 1991 to 2023
    year_column = str(year)
    
    # Check if the year exists as a column in the dataframe
    if year_column in literacy_data_pd.columns:
        # Create a new DataFrame with 'country', 'alpha3', and the value of that year
        df_year = literacy_data_pd[['country', 'alpha3', year_column]].copy()
        
        # Rename the column to 'literacy' instead of 'value'
        df_year = df_year.rename(columns={year_column: 'literacy'})
        
        # Add a new column 'year' to store the current year
        df_year['year'] = year
        
        # Rearrange the columns to ['country', 'year', 'alpha3', 'literacy']
        df_year = df_year[['country', 'year', 'alpha3', 'literacy']]
        
        # Append the DataFrame to the list
        df_list.append(df_year)

# Concatenate all the DataFrames in the list into a single DataFrame
merged_literacy_data = pd.concat(df_list, ignore_index=True)

# Optionally, inspect the merged DataFrame
print(merged_literacy_data.head())
# Out:
#                        country  year alpha3   literacy
# 0  Africa Eastern and Southern  1991    AFE  58.141190
# 1   Africa Western and Central  1991    AFW  44.823318
# 2                      Albania  1991    ALB        NaN
# 3                   Arab World  1991    ARB  55.813911
# 4                      Armenia  1991    ARM        NaN

# %%
population_pd = pd.read_csv('./processed_datasets/population.csv')
population_pd
# Out:
#      Unnamed: 0                 Country Name Country Code         1990  \
# 0             0                        Aruba          ABW      65712.0
# 1             1  Africa Eastern and Southern          AFE  309890664.0
# 2             2                  Afghanistan          AFG   10694796.0
# 3             3   Africa Western and Central          AFW  206739024.0
# 4             4                       Angola          AGO   11828638.0
# ..          ...                          ...          ...          ...
# 261         261                       Kosovo          XKX    1964986.0
# 262         262                  Yemen, Rep.          YEM   13375121.0
# 263         263                 South Africa          ZAF   39877570.0
# 264         264                       Zambia          ZMB    7686401.0
# 265         265                     Zimbabwe          ZWE   10113893.0
#
#             1991         1992         1993         1994         1995  \
# ...

# %%
# Initialize an empty list to store DataFrames
df_list = []

for year in range(1990, 2021):  # Assuming the range of years is from 1990 to 2020
    year_column = str(year)
    
    # Check if the year exists as a column in the dataframe
    if year_column in population_pd.columns:
        # Create a new DataFrame with 'Country Name', 'Country Code', and the value of that year
        df_year = population_pd[['Country Name', 'Country Code', year_column]].copy()
        
        # Rename the columns as per the required structure
        df_year = df_year.rename(columns={
            'Country Name': 'country',
            'Country Code': 'alpha3',
            year_column: 'population'  # Rename to 'population' instead of 'value'
        })
        
        # Add a new column 'year' to store the current year
        df_year['year'] = year
        
        # Rearrange the columns to ['country', 'year', 'alpha3', 'population']
        df_year = df_year[['country', 'year', 'alpha3', 'population']]
        
        # Append the DataFrame to the list
        df_list.append(df_year)

# Concatenate all the DataFrames in the list into a single DataFrame
merged_population_data = pd.concat(df_list, ignore_index=True)

# Optionally, inspect the merged DataFrame
print(merged_population_data.head())
# Out:
#                        country  year alpha3   population
# 0                        Aruba  1990    ABW      65712.0
# 1  Africa Eastern and Southern  1990    AFE  309890664.0
# 2                  Afghanistan  1990    AFG   10694796.0
# 3   Africa Western and Central  1990    AFW  206739024.0
# 4                       Angola  1990    AGO   11828638.0

# %%
poverty_data_pd = pd.read_csv('./processed_datasets/poverty_data.csv')
poverty_data_pd
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name Indicator Code  1960  \
# 0    Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# 1    Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# 2    Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# 3    Poverty headcount ratio at national poverty li...    SI.POV.NAHC   NaN
# ...

# %%
# Initialize an empty list to store DataFrames
df_list = []

for year in range(1990, 2021):  # Assuming the range of years is from 1990 to 2020
    year_column = str(year)
    
    # Check if the year exists as a column in the dataframe
    if year_column in poverty_data_pd.columns:
        # Create a new DataFrame with 'Country Name', 'Country Code', and the value of that year
        df_year = poverty_data_pd[['Country Name', 'Country Code', year_column]].copy()
        
        # Rename the columns as per the required structure
        df_year = df_year.rename(columns={
            'Country Name': 'country',
            'Country Code': 'alpha3',
            year_column: 'poverty'  
        })
        
        # Add a new column 'year' to store the current year
        df_year['year'] = year
        
        # Rearrange the columns to ['country', 'year', 'alpha3', 'population']
        df_year = df_year[['country', 'year', 'alpha3', 'poverty']]
        
        # Append the DataFrame to the list
        df_list.append(df_year)

# Concatenate all the DataFrames in the list into a single DataFrame
merged_poverty_data = pd.concat(df_list, ignore_index=True)

# Optionally, inspect the merged DataFrame
print(merged_poverty_data.head())
# Out:
#                        country  year alpha3  poverty
# 0                        Aruba  1990    ABW      NaN
# 1  Africa Eastern and Southern  1990    AFE      NaN
# 2                  Afghanistan  1990    AFG      NaN
# 3   Africa Western and Central  1990    AFW      NaN
# 4                       Angola  1990    AGO      NaN

# %%
suicides_df = pd.read_csv('./processed_datasets/suicides_clean.csv')
print(suicides_df)
# Out:
#       year              country  suicides_no
# 0     1985  Antigua and Barbuda            0
# 1     1985            Argentina         1988
# 2     1985            Australia         1861
# 3     1985              Austria         2091
# 4     1985              Bahamas            1
# ...    ...                  ...          ...
# 2316  2016          Netherlands         1886
# 2317  2016                Qatar           68
# 2318  2016              Romania         1953
# 2319  2016               Sweden         1130
# 2320  2016             Thailand         4117
#
# [2321 rows x 3 columns]

# %%
# Filter the DataFrame for the years between 1990 and 2020 (inclusive)
filtered_suicides_df = suicides_df[(suicides_df['year'] >= 1990) & (suicides_df['year'] <= 2020)]

# Optionally, inspect the filtered DataFrame
print(filtered_suicides_df.head())
# Out:
#      year              country  suicides_no
# 251  1990  Antigua and Barbuda            1
# 252  1990            Argentina         2140
# 253  1990              Armenia           93
# 254  1990            Australia         2202
# 255  1990              Austria         1825

# %%
# Start with the first DataFrame (e.g., gini data)
merged_df = merged_gini_data

# Now merge it iteratively with other DataFrames, specifying suffixes to avoid duplicates
merged_df = pd.merge(merged_df, merged_literacy_data, on=['country', 'year'], how='outer', suffixes=('_gini', '_literacy'))
merged_df = pd.merge(merged_df, merged_population_data, on=['country', 'year'], how='outer', suffixes=('', '_population'))
merged_df = pd.merge(merged_df, merged_poverty_data, on=['country', 'year'], how='outer', suffixes=('', '_poverty'))
merged_df = pd.merge(merged_df, filtered_suicides_df, on=['country', 'year'], how='outer', suffixes=('', '_suicides'))

# Optionally inspect the merged DataFrame
print(merged_df.dropna().size)
# Out:
# 1880

# %%
# Out:
# 418
