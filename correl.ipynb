# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
forest_data = pd.read_csv('datasets/forest_cover.csv')
land_data = pd.read_csv('datasets/land_util.csv')
car_data = pd.read_csv('datasets/car_park.csv')
air_poll = pd.read_csv('datasets/pollution.csv')

# %%
forest_data.set_index('Country', inplace=True)

# %%
air_poll.head()
# Out:
#                      WHO Region ISO3 WHO Country Name City or Locality  \
# 0  Eastern Mediterranean Region  AFG      Afghanistan            Kabul
# 1               European Region  ALB          Albania           Durres
# 2               European Region  ALB          Albania           Durres
# 3               European Region  ALB          Albania          Elbasan
# 4               European Region  ALB          Albania          Elbasan
#
#    Measurement Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0              2019         119.77           NaN          NaN
# 1              2015            NaN         17.65        26.63
# 2              2016          14.32         24.56        24.78
# 3              2015            NaN           NaN        23.96
# 4              2016            NaN           NaN        26.26
#
#    PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                        18.0                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    NO2 temporal coverage (%)  \
# 0                        NaN
# 1                  83.961187
# 2                  87.932605
# 3                  97.853881
# 4                  96.049636
#
#                                            Reference  \
# 0  U.S. Department of State, United States Enviro...
# 1   European Environment Agency (downloaded in 2021)
# 2   European Environment Agency (downloaded in 2021)
# 3   European Environment Agency (downloaded in 2021)
# 4   European Environment Agency (downloaded in 2021)
#
#   Number and type of monitoring stations  Version of the database  Status
# 0                                    NaN                     2022     NaN
# 1                                    NaN                     2022     NaN
# 2                                    NaN                     2022     NaN
# 3                                    NaN                     2022     NaN
# 4                                    NaN                     2022     NaN

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(air_poll):
    # Drop columns: 'PM10 temporal coverage (%)', 'NO2 temporal coverage (%)' and 8 other columns
    air_poll = air_poll.drop(columns=['PM10 temporal coverage (%)', 'NO2 temporal coverage (%)', 'PM25 temporal coverage (%)', 'Reference', 'Number and type of monitoring stations', 'Version of the database', 'Status', 'City or Locality', 'WHO Region', 'ISO3'])
    return air_poll

air_poll_clean = clean_data(air_poll.copy())
air_poll_clean
# Out:
#       WHO Country Name  Measurement Year  PM2.5 (μg/m3)  PM10 (μg/m3)  \
# 0          Afghanistan              2019         119.77           NaN
# 1              Albania              2015            NaN         17.65
# 2              Albania              2016          14.32         24.56
# 3              Albania              2015            NaN           NaN
# 4              Albania              2016            NaN           NaN
# ...                ...               ...            ...           ...
# 32186     South Africa              2015           7.47         24.64
# 32187     South Africa              2016           8.42         33.28
# 32188     South Africa              2017           6.83         20.49
# 32189     South Africa              2018           6.10         17.99
# 32190     South Africa              2016            NaN           NaN
#
#        NO2 (μg/m3)
# 0              NaN
# 1            26.63
# 2            24.78
# 3            23.96
# 4            26.26
# ...            ...
# 32186         7.64
# 32187         7.27
# 32188         8.72
# 32189         7.15
# 32190        17.85
#
# [32191 rows x 5 columns]

# %%
air_poll_clean = air_poll_clean.loc[air_poll_clean['Measurement Year'] == 2019]
air_poll_clean = air_poll_clean.groupby('WHO Country Name').mean().drop(columns = 'Measurement Year')

# %%
#air_poll_clean.set_index('WHO Country Name', inplace=True)

# %%
merged = air_poll_clean.join(forest_data).drop(columns = 'NUTS_CODE')

# %%
land_data.drop(columns=['NUTS_CODE', 'YEAR'], inplace=True)

# %%
land_data.groupby('Country').mean()
# Out:
#                       STAT
# Country
# Austria          80.700000
# Belgium          85.925000
# Bulgaria         40.100000
# Croatia          59.575000
# Cyprus           53.575000
# Czechia          78.300000
# Denmark          91.125000
# EU28             65.135000
# Estonia          65.900000
# Finland          77.100000
# France           47.300000
# Germany          78.733333
# Greece           81.500000
# Hungary          76.000000
# Ireland          52.500000
# Italy            44.275000
# Latvia           61.700000
# Lithuania        82.850000
# Netherlands      53.525000
# Poland           74.800000
# Portugal         72.133333
# Romania          55.225000
# Slovakia         64.700000
# Slovenia         36.450000
# Spain            55.325000
# Sweden          110.050000
# United Kingdom   46.325000

# %%
land_data.set_index('Country', inplace=True)

# %%
merged = merged.join(land_data)
merged.rename(columns = {'STAT': 'Agricultural land usage'}, inplace=True)

# %%
#merged.drop(columns ='Country', inplace=True)

# %%
#merged.set_index('Country', inplace=True)

# %%
life = pd.read_csv('datasets/life_exp.csv')

# %%
life.columns = life.iloc[0,:]

# %%
life.drop(index=0, inplace=True)

# %%
life.columns
# Out:
# Index(['Countries, territories and areas', 'Year', 'Both sexes'], dtype='object', name=0)

# %%
life.drop(columns='Year', inplace=True)

# %%
life.rename(columns={'Both sexes': 'Life expectancy', 'Countries, territories and areas': 'Country'}, inplace=True)
life.set_index('Country', inplace=True)

# %%
merged
# Out:
#                           PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)    NFI2015  \
# WHO Country Name
# Afghanistan                  119.770000           NaN          NaN        NaN
# Albania                       10.320000           NaN          NaN   785000.0
# Algeria                       21.530000           NaN          NaN        NaN
# Andorra                             NaN     24.580000    31.010000        NaN
# Argentina                           NaN     25.500000    18.250000        NaN
# ...                                 ...           ...          ...        ...
# United Kingdom                 9.592131     16.043036    21.674393  3155000.0
# United Kingdom                 9.592131     16.043036    21.674393  3155000.0
# United States of America       7.319298     18.631515    12.861250        NaN
# Uzbekistan                    41.960000           NaN          NaN        NaN
# Viet Nam                      39.355000           NaN          NaN        NaN
#
#                             CLC2018    HRL2015  Agricultural land usage
# WHO Country Name
# Afghanistan                     NaN        NaN                      NaN
# Albania                    711124.0  1091214.3                      NaN
# Algeria                         NaN        NaN                      NaN
# Andorra                         NaN        NaN                      NaN
# Argentina                       NaN        NaN                      NaN
# ...                             ...        ...                      ...
# United Kingdom            2046627.0  2770252.0                     48.0
# United Kingdom            2046627.0  2770252.0                     50.5
# United States of America        NaN        NaN                      NaN
# Uzbekistan                      NaN        NaN                      NaN
# Viet Nam                        NaN        NaN                      NaN
#
# [149 rows x 7 columns]

# %%
merged = merged.join(life)

# %%
merged.drop(columns = merged.iloc[:, [1, 3, 5]], inplace=True)

# %%
corr_matrix = merged.corr()

plt.style.use('dark_background')

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
