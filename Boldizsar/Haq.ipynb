# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv('./kaggle/input/healthcare-access-and-quality-index.csv')
df
# Out:
#            Entity Code  Year  HAQ Index (IHME (2017))
# 0     Afghanistan  AFG  1990                     24.7
# 1     Afghanistan  AFG  1995                     24.5
# 2     Afghanistan  AFG  2000                     24.8
# 3     Afghanistan  AFG  2005                     27.1
# 4     Afghanistan  AFG  2010                     29.4
# ...           ...  ...   ...                      ...
# 1327     Zimbabwe  ZWE  1995                     49.5
# 1328     Zimbabwe  ZWE  2000                     45.4
# 1329     Zimbabwe  ZWE  2005                     41.8
# 1330     Zimbabwe  ZWE  2010                     42.1
# 1331     Zimbabwe  ZWE  2015                     48.7
#
# [1332 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('./kaggle/input/healthcare-access-and-quality-index.csv')

# Rename columns for easier access
df.columns = ['Entity', 'Code', 'Year', 'HAQ_Index']

# Define the countries of interest
countries_of_interest = ["Hungary", "Slovakia", "Romania", "Poland", "Croatia", "Serbia", "Montenegro", "Albania", 
                         "Czechia", "Bulgaria", "Greece", "North Macedonia", "Moldova", "Lithuania", "Latvia", 
                         "Germany", "Austria", "Switzerland", "Slovenia", "Sweden", "Estonia"]

# Filter the DataFrame to include only these countries
df_filtered = df[df['Entity'].isin(countries_of_interest)]

# Set up the plot
plt.figure(figsize=(14, 8))

# Plot each country
for country in countries_of_interest:
    # Subset the data for the specific country
    country_data = df_filtered[df_filtered['Entity'] == country]
    
    # Plot data
    plt.plot(country_data['Year'], country_data['HAQ_Index'], label=country)

# Add labels and title
plt.title('HAQ Index for Selected Countries Over Time', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('HAQ Index (IHME 2017)', fontsize=12)

# Add legend outside the plot
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()

# %%
# Step 1: Filter data for 2020 and include ISO3 codes
life_expectancy_2020_col = 'Life Expectancy at Birth (2020)'

# Include 'ISO3', 'Country', and 'Life Expectancy at Birth (2020)' columns
ranking_2020 = selected_countries[['Country', 'ISO3', life_expectancy_2020_col]].copy()

# Step 2: Sort the countries by life expectancy in 2020 in descending order
ranking_2020 = ranking_2020.sort_values(by=life_expectancy_2020_col, ascending=False)

# Step 3: Reset index for better readability
ranking_2020.reset_index(drop=True, inplace=True)


ranking_2020
# Out:
#                    Country ISO3  Life Expectancy at Birth (2020)
# 0              Switzerland  CHE                          83.0670
# 1                  Austria  AUT                          81.5036
# 2                  Germany  DEU                          81.1472
# 3                   Greece  GRC                          80.9092
# 4                 Slovenia  SVN                          80.4409
# 5                  Czechia  CZE                          78.5746
# 6                  Croatia  HRV                          77.9845
# 7                 Slovakia  SVK                          77.0054
# 8                   Poland  POL                          76.9424
# 9               Montenegro  MNE                          76.2575
# 10  Bosnia and Herzegovina  BIH                          76.2254
# 11                 Hungary  HUN                          75.7297
# 12                  Latvia  LVA                          75.4526
# 13                  Serbia  SRB                          75.4057
# 14                 Romania  ROU                          75.3456
# 15         North Macedonia  MKD                          75.1677
# 16               Lithuania  LTU                          75.0676
# 17                Bulgaria  BGR                          73.6453
# 18                 Moldova  MDA                          70.1665

# %%
# Step 5: Visualize the top 10 ranked countries for 2020 life expectancy
plt.figure(figsize=(10, 6))
plt.barh(ranking_2020['Country'].head(30), ranking_2020[life_expectancy_2020_col].head(30), color='skyblue')
plt.xlabel('Life Expectancy at Birth (2020)')
plt.title('Top 10 European Countries by Life Expectancy in 2020')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest at the top
plt.show()
