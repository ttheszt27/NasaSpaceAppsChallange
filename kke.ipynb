# %%
import pandas as pd
import os

# %%
countries_base = ["Hungary", "Slovakia", "Romania", "Poland", "Croatia", "Serbia", "Montenegro", "Albania", "Czechia", "Bulgaria", "Greece", "North Macedonia"
             , "Moldova", "Lithuania", "Latvia", "Bosnia and Herzegovina"]
countries_ref = ["Germany", "Austria", "Switzerland", "Slovenia"]

countries = countries_base + countries_ref

# %%
literacy_data = pd.read_csv('datasets/literacy.csv')
gini_data = pd.read_csv('datasets/gini.csv')
poverty_data = pd.read_csv('datasets/poverty.csv')
mensa_data = pd.read_csv('datasets/mensa.csv').drop(columns = 'MensaMembersByCountryMembershipFee')
population_data = pd.read_csv('datasets/population.csv')
public_transport_data = pd.read_csv('datasets/public_transport.csv')
electricity_data = pd.read_csv('datasets/electricity.csv')

# %%
def clean_and_filter(df):
    # Filter columns for years above 1990
    df = df.loc[:, df.columns > '1990']

    df = df.drop(columns=['Indicator Name', 'Indicator Code', 'Unnamed: 68'], errors='ignore')

    df = df.rename(columns={'Country Name': 'country', 'Country Code': 'alpha3'})
    
    # Calculate the threshold for dropping rows (20% of the total number of columns)
    threshold = df.shape[1] * 0.2
    
    # Drop rows where more than 80% of the cells are NaN
    df = df.dropna(thresh=threshold)
    
    return df

# %%
#literacy_data = literacy_data.drop(columns = ['Indicator Name', 'Indicator Code', 'Unnamed: 68'])

literacy_data = clean_and_filter(literacy_data)

literacy_data
# Out:
#                          country alpha3       1991       1992       1993  \
# 1    Africa Eastern and Southern    AFE  58.141190  58.530640  58.912601
# 3     Africa Western and Central    AFW  44.823318  45.163380  46.002171
# 5                        Albania    ALB        NaN        NaN        NaN
# 7                     Arab World    ARB  55.813911  56.863861  57.682941
# 10                       Armenia    ARM        NaN        NaN        NaN
# ..                           ...    ...        ...        ...        ...
# 257                     Viet Nam    VNM        NaN        NaN        NaN
# 258                      Vanuatu    VUT        NaN        NaN        NaN
# 259                        World    WLD  75.198761  75.645752  76.059624
# 263                 South Africa    ZAF        NaN        NaN        NaN
# 264                       Zambia    ZMB        NaN        NaN        NaN
#
#           1994       1995       1996       1997       1998  ...       2014  \
# 1    59.526852  59.921940  60.434929  61.174061  61.408710  ...  69.834770
# 3    46.869511  47.017632  47.806450  48.828880  50.175579  ...  54.006760
# 5          NaN        NaN        NaN        NaN        NaN  ...        NaN
# 7    58.448780  59.594292  60.881039  61.828331  63.036888  ...  77.577873
# 10         NaN        NaN        NaN        NaN        NaN  ...        NaN
# ..         ...        ...        ...        ...        ...  ...        ...
# 257        NaN        NaN        NaN        NaN        NaN  ...        NaN
# 258  68.699997        NaN        NaN        NaN        NaN  ...  84.699997
# 259  76.462769  76.868942  77.258171  79.248680  80.433929  ...  85.433708
# 263        NaN        NaN  82.402100        NaN        NaN  ...  94.139900
# 264        NaN        NaN        NaN        NaN        NaN  ...        NaN
#
#           2015       2016       2017       2018       2019       2020  \
# 1    70.313423  71.095200  71.009071  71.392616  72.634972  72.785622
# 3    54.818321  55.437920  56.485538  59.568459  59.511719  59.617512
# 5          NaN        NaN        NaN        NaN        NaN        NaN
# 7    74.981209  76.386726  77.170303  74.286133  74.603661  75.022881
# 10         NaN  99.744408  99.736069        NaN        NaN  99.788612
# ..         ...        ...        ...        ...        ...        ...
# 257        NaN        NaN        NaN        NaN  95.753868        NaN
# 258        NaN        NaN        NaN        NaN        NaN        NaN
# 259  85.601830  86.061157  86.288231  86.339050  86.489601  86.711510
# 263  94.367920        NaN  87.046669        NaN  95.022972        NaN
# 264        NaN        NaN        NaN        NaN        NaN  87.500000
#
#           2021       2022  2023
# 1    72.581161  72.600403   NaN
# 3    60.034611  60.312698   NaN
# 5          NaN  98.500000   NaN
# 7    75.231178  75.171532   NaN
# 10         NaN        NaN   NaN
# ..         ...        ...   ...
# 257        NaN  96.133263   NaN
# 258  89.099998        NaN   NaN
# 259  86.852753  87.011749   NaN
# 263  90.001358        NaN   NaN
# 264        NaN        NaN   NaN
#
# [114 rows x 35 columns]

# %%
gini_data = clean_and_filter(gini_data)

# %%
global_data = pd.read_csv('datasets/world-data-2023.csv')

# %%
electricity_data = clean_and_filter(electricity_data)

# %%
from numpy import astype


mensa_data.rename(columns={'MensaMembersByCountry': 'members'}, inplace=True)
mensa_data.dropna(inplace=True) 
mensa_data['members'] = mensa_data['members'].astype(int)
mensa_data
# Out:
#                  country  members
# 0                  India     1500
# 1          United States    50000
# 2              Indonesia      175
# 3               Pakistan      250
# 4                 Brazil     1300
# 5                 Mexico      400
# 6                  Japan     4500
# 7            Philippines      160
# 9                Germany    16000
# 10        United Kingdom    19000
# 11                France     4000
# 12          South Africa     1300
# 13                 Italy     1800
# 14              Colombia      100
# 15           South Korea     2400
# 16                 Spain     1750
# 17             Argentina      400
# 18                Canada     2022
# 19                Poland     2000
# 20              Malaysia      900
# 21                  Peru      100
# 22             Australia     2500
# 23                Taiwan      600
# 24               Romania      800
# 25           Netherlands     4300
# 26               Belgium      500
# 27  United Arab Emirates       50
# 28        Czech Republic     6042
# 29                Sweden     7200
# 30                Greece     1300
# 31               Hungary     4700
# 32               Austria     1000
# 33           Switzerland     1800
# 34             Hong Kong      300
# 35              Bulgaria      260
# 36                Serbia     1100
# 37               Denmark     2000
# 38             Singapore     1400
# 39               Finland     3300
# 40                Norway     2400
# 41              Slovakia      750
# 42               Ireland      850
# 43           New Zealand      600
# 44               Croatia     1300
# 45              Slovenia      250
# 46       North Macedonia      100
# 47                Cyprus      110
# 48            Luxembourg      100
# 49            Montenegro      200

# %%
public_transport_data = clean_and_filter(public_transport_data)

# %%
population_data = clean_and_filter(population_data)

# %%
datasets = [literacy_data, gini_data, poverty_data, mensa_data, population_data, public_transport_data, electricity_data]

os.makedirs('processed_datasets', exist_ok=True)

# List of dataset names for exporting
dataset_names = ['literacy_data', 'gini_data', 'poverty_data', 'mensa_data', 'population_data', 'public_transport_data', 'electricity_data']

# Export each dataset to a CSV file in the processed_datasets folder
for dataset, name in zip(datasets, dataset_names):
    dataset.to_csv(f'processed_datasets/{name}.csv', index=False)
